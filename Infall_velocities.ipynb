# %%
# %pylab 
import matplotlib.pyplot as plt
data_dir="/data/nugrid_apod2/"
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### plotting function

# %%
def plot_infall_vel(xaxis,ax, path_exp,path_wind,label,shape,marker,markevery,color):
        '''
        Plots the infall velocity vs free-fall time or mass coordinate

        Parameter
        xaxis: 'ff': free-fall time
                'mass' : mass coordinate
        

        '''

        plt.figure(fig)
        import nugridse as mp
        sefiles=mp.se(path_exp)
        cyc = int(sefiles.se.cycles[0])
        cyc = cyc - 1
        sefiles=mp.se(path_wind)



        G =6.67259e-8 #cm^3 g^-1 s^-2 
        msun = 1.9891e33 #Msun in g

        r = sefiles.get(cyc,'radius') #cm
        rho = sefiles.get(cyc,'rho') #g/cm3
        m = sefiles.get(cyc,'mass')*msun # cm
        print 'cycle lookup',cyc
        r = np.array(r)

        t_ff = np.pi/2 * r**(3./2.)/np.sqrt(2*G*m) #s

        v_ff = np.sqrt(2*G*m/r)

        mdot = 4.*np.pi*r**2 * rho * v_ff /msun
        print 'plot'
        if xaxis=='ff':
                ax.plot(t_ff,mdot,label=label,linestyle=shape,markevery=markevery,marker=marker,color=color)
                plt.xlabel(r't$_{ff}$ [s]')
                plt.xscale('log')

        if xaxis=='mass':
                ax.plot(m/msun,mdot,label=label,linestyle=shape,markevery=markevery,marker=marker,color=color)
                plt.xlabel("M [M$_{\odot}$]")

        plt.ylabel(r"$\dot{M}$ [M$_{\odot}$/s]")
        plt.yscale('log')

# %% [markdown]
# #### Input parameter, general

# %%
fign = 1
fig=fign
markevery=50
props = dict(boxstyle='square', facecolor='w', alpha=1)
metals=['Z=0.02','Z=0.01','Z=0.001','Z=0.0001']
marker=['o','^','s','D']
shape=['-','--',':','-.']
color=['r','b','g','k']

xaxis='ff'
#xaxis='mass'
props=dict(boxstyle='square',facecolor='w',alpha=1)
path=data_dir+'/data/set1ext'
textr=0.25
log=True

# %% [markdown]
# #### create figure

# %%
f, axarr = plt.subplots(2, 2)
for i in range(len(metals)):

        if i==0:
                ax=plt.sca(axarr[0,0])
                axarr[0,0].text(textr, 0.94, metals[i], transform=axarr[0,0].transAxes, fontsize=16,verticalalignment='top', bbox=props)
                path_s=path+'/set1.2'
                k=0
                for m in [12.,15.,20.,25.]:
                            path_exp1=path_s+'/see_exp/M'+str(m)+'Z2.0e-02.delay'
                            path_wind1=path_s+'/see_wind/M'+str(m)+'Z2.0e-02/M'+str(m)+'Z2.0e-02'
                            label=str(m)+'$M_{\odot}$' #, Z='+str(metals[i])
                            plot_infall_vel(xaxis,axarr[0,0], path_exp1,path_wind1,label=label,shape=shape[k],marker=marker[k],markevery=markevery,color=color[k])
                            k=k+1
                plt.legend(loc=1,fontsize=14)
                #axarr[0,0].locator_params(nbins=4, axis='x')
                plt.ylim(1e-8,1e2)
                axarr[0,0].set_xlabel('')
                axarr[0,0].set_xticklabels([])
        if i==1:
                ax=plt.sca(axarr[0,1])
                axarr[0,1].text(textr, 0.94, metals[i], transform=axarr[0,1].transAxes, fontsize=16,verticalalignment='top', bbox=props)
                path_s=path+'/set1.1'
                k=0
                for m in [12.,15.,20.,25.]:
                        try:
                                path_exp1=path_s+'/see_exp/M'+str(m)+'Z1.0e-02.delay'
                                path_wind1=path_s+'/see_wind/M'+str(m)+'Z1.0e-02/M'+str(m)+'Z1.0e-02'
                                label=str(m)+'$M_{\odot}$' #, Z='+str(metals[i])
                                plot_infall_vel(xaxis,axarr[0,1], path_exp1,path_wind1,label=label,shape=shape[k],marker=marker[k],markevery=markevery,color=color[k])
                                k=k+1
                        except:
                                print 'faulty data ',label
                                pass
                plt.legend(loc=1,fontsize=14)
                #axarr[0,0].locator_params(nbins=4, axis='x')
                plt.ylim(1e-8,1e2)
                axarr[0,1].set_xlabel('')
                axarr[0,1].set_xticklabels([])
                plt.legend().set_visible(False)
        if i==2:
                ax=plt.sca(axarr[1,0])
                axarr[1,0].text(textr, 0.94, metals[i], transform=axarr[1,0].transAxes, fontsize=16,verticalalignment='top', bbox=props)
                path_s=path+'/set1.4a'
                k=0
                for m in [12.,15.,20.,25.]:
                        try:
                                path_exp1=path_s+'/see_exp/M'+str(m)+'Z1.0e-03.delay'
                                path_wind1=path_s+'/see_wind/M'+str(m)+'Z1.0e-03/M'+str(m)+'Z1.0e-03'
                                label=str(m)+'$M_{\odot}$' #, Z='+str(metals[i])
                                plot_infall_vel(xaxis,axarr[1,0], path_exp1,path_wind1,label=label,shape=shape[k],marker=marker[k],markevery=markevery,color=color[k])
                                k=k+1
                        except:
                                print 'faulty data ',label
                                pass
                plt.legend(loc=1,fontsize=14)
                #axarr[0,0].locator_params(nbins=4, axis='x')
                plt.ylim(1e-8,1e2)
                plt.legend().set_visible(False)

        if i==3:
                ax=plt.sca(axarr[1,1])
                axarr[1,1].text(textr, 0.94, metals[i], transform=axarr[1,1].transAxes, fontsize=16,verticalalignment='top', bbox=props)
                path_s=path+'/set1.5a'
                k=0
                for m in [12.,15.,20.,25.]:
                        try:
                                path_exp1=path_s+'/see_exp/M'+str(m)+'Z1.0e-04.delay'
                                path_wind1=path_s+'/see_wind/M'+str(m)+'Z1.0e-04/M'+str(m)+'Z1.0e-04'
                                label=str(m)+'$M_{\odot}$' #, Z='+str(metals[i])
                                plot_infall_vel(xaxis,axarr[1,1], path_exp1,path_wind1,label=label,shape=shape[k],marker=marker[k],markevery=markevery,color=color[k])
                                k=k+1
                        except:
                                print 'faulty data ',label
                                pass
                plt.legend(loc=1,fontsize=14)
                #axarr[0,0].locator_params(nbins=4, axis='x')
                plt.ylim(1e-8,1e2)
                plt.legend().set_visible(False)


f.set_size_inches(12,10,forward=True)
f.subplots_adjust(hspace=0.1,wspace=0.4)
# Out:
# <img src="data:image/png;base64,...">
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_exp/M12.0Z2.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_wind/M12.0Z2.0e-02/M12.0Z2.0e-02
# Closing plot_tools
# cycle lookup 8900
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_exp/M15.0Z2.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_wind/M15.0Z2.0e-02/M15.0Z2.0e-02
# Closing plot_tools
# cycle lookup 20500
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_exp/M20.0Z2.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_wind/M20.0Z2.0e-02/M20.0Z2.0e-02
# Closing plot_tools
# cycle lookup 21000
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_exp/M25.0Z2.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.2/see_wind/M25.0Z2.0e-02/M25.0Z2.0e-02
# Closing plot_tools
# cycle lookup 23497
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_exp/M12.0Z1.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_wind/M12.0Z1.0e-02/M12.0Z1.0e-02
# Closing plot_tools
# cycle lookup 8150
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_exp/M15.0Z1.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_wind/M15.0Z1.0e-02/M15.0Z1.0e-02
# Closing plot_tools
# cycle lookup 18059
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_exp/M20.0Z1.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_wind/M20.0Z1.0e-02/M20.0Z1.0e-02
# Closing plot_tools
# cycle lookup 19485
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_exp/M25.0Z1.0e-02.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.1/see_wind/M25.0Z1.0e-02/M25.0Z1.0e-02
# Closing plot_tools
# cycle lookup 25098
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_exp/M12.0Z1.0e-03.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_wind/M12.0Z1.0e-03/M12.0Z1.0e-03
# Closing plot_tools
# cycle lookup 7298
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_exp/M15.0Z1.0e-03.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_wind/M15.0Z1.0e-03/M15.0Z1.0e-03
# Closing plot_tools
# cycle lookup 21529
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_exp/M20.0Z1.0e-03.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_wind/M20.0Z1.0e-03/M20.0Z1.0e-03
# Closing plot_tools
# cycle lookup 27733
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_exp/M25.0Z1.0e-03.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.4a/see_wind/M25.0Z1.0e-03/M25.0Z1.0e-03
# Closing plot_tools
# cycle lookup 20598
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_exp/M12.0Z1.0e-04.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_wind/M12.0Z1.0e-04/M12.0Z1.0e-04
# Closing plot_tools
# cycle lookup 7798
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_exp/M15.0Z1.0e-04.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_wind/M15.0Z1.0e-04/M15.0Z1.0e-04
# Closing plot_tools
# cycle lookup 20206
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_exp/M20.0Z1.0e-04.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_wind/M20.0Z1.0e-04/M20.0Z1.0e-04
# Closing plot_tools
# cycle lookup 11873
# plot
# Closing plot_tools
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_exp/M25.0Z1.0e-04.delay
# A test  []
# Sorry, there is no A vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no Z vector. This can cause problems for reading abundances. Continue...
# Sorry, there is no isomeric state vector. Continue...
# This file does not contain any tables.  Isotopic data must be contained elsewhere.
# sedir =  /apod2/NuGrid/data/set1ext/set1.5a/see_wind/M25.0Z1.0e-04/M25.0Z1.0e-04
# Closing plot_tools
# cycle lookup 17170
# plot
# Closing plot_tools
