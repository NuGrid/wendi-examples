# %% [markdown]
# # Demo for ppn run analysis

# %%
# %pylab nbagg
from nugridpy  import ppn
from nugridpy  import utils
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Initialize ppn instances

# %%
cd /user/scratch14/NuGrid/NuPPN/examples/ppn_iprocess_1zone
pa = ppn.abu_vector('..')
px = ppn.xtime('..')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8ccf6f6958d6> in <module>()
#       1
# ----> 2 cd /user/scratch14/NuGrid/NuPPN/examples/ppn_iprocess_1zone
#       3 pa = ppn.abu_vector('.')
#       4 px = ppn.xtime('.')
#
# NameError: name 'cd' is not defined

# %%
pwd
# Out:
# '/user/scratch14/NuGrid/NuPPN/examples/ppn_iprocess_1zone/python-scripts'

# %% [markdown]
# ## The xtime instance

# %% [markdown]
# ### What is in the xtime instance?

# %%
px.cols
# Out:
# ['cycle',
#  'time',
#  't9',
#  'rho',
#  'sum(yps)',
#  'ye',
#  'NEUT',
#  'PROT',
#  'H   2',
#  'HE  3',
#  'HE  4',
#  'BE  7',
#  'B   8',
#  'LI  7',
#  'C  11',
#  'B  11',
#  'C  12',
#  'C  13',
#  'N  13',
#  'N  14',
#  'C  14',
#  'N  15',
#  'O  16',
#  'O  17',
#  'O  18',
#  'F  17',
#  'F  18',
#  'F  19',
#  'NE 20',
#  'NE 21',
#  'NE 22',
#  'NA 22',
#  'NA 23',
#  'MG 23',
#  'MG 24',
#  'MG 25',
#  'MG 26',
#  'AL 26',
#  'AL 27',
#  'SI 27',
#  'SI 28',
#  'SI 29',
#  'SI 30',
#  'P  31',
#  'S  31',
#  'BE  8',
#  'O  14',
#  'O  15',
#  'NA 21',
#  'AL 25',
#  'P  29',
#  'P  30',
#  'PB206',
#  'PB207',
#  'BI211',
#  'PO210',
#  'H   3',
#  'HE  6',
#  'LI  8',
#  'LI  9',
#  'BE 10',
#  'BE 11',
#  'BE 12',
#  'B  12',
#  'B  13',
#  'B  14',
#  'C  15',
#  'C  16',
#  'C  17',
#  'C  18',
#  'N  11',
#  'N  12',
#  'N  16',
#  'N  17',
#  'N  18',
#  'N  19',
#  'N  20',
#  'N  21',
#  'O  13',
#  'O  19',
#  'O  20',
#  'O  21',
#  'O  22',
#  'F  20',
# ...

# %% [markdown]
# ## Abundance evolution plots
# This uses the plot method.

# %%
specs=['PROT','HE  4','C  12','N  14','O  16']
i=0
for spec in specs:
    px.plot('time',spec,logy=True,logx=True,shape=utils.linestyle(i)[0],show=False,title='')
    i += 1
ylim(-5,0.2)
legend(loc=0)
xlabel('$\log t / \mathrm{min}$')
ylabel('$\log X \mathrm{[mass fraction]}$')
# Out:
# <img src="data:image/png;base64,...">
