# %%
# %pylab inline
from nugridpy import ppn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /user/NuGrid/NuPPN/frames/ppn/RUN1/
# Out:
# /user/NuGrid/NuPPN/frames/ppn/RUN1

# %%
p=ppn.abu_vector('.')
#p.movie([30,31],plotstyle='iso_abund',movname='ttt.mp4',stable=True,decayed=True)
# Out:
# 39 cycle numbers found in .
# Ranging from 00000 to 00038
# Range may not be continuous. To display all available cycles, print <abu_vector_instance>.files

# %% [markdown]
# ## Workaround

# %%
# %%capture
# !rm -f IsoAbund*.png
cycs=list(range(4,31,2))
p.iso_abundMulti(cycs,stable=True, decayed=True,amass_range=[5,40])

# %%
# %%capture
# %%bash
prefix=IsoAbund
size=640
/opt/mesasdk/bin/ffmpeg  -y -f image2 -r 6  -pattern_type \
     glob -i "$prefix*.png" -preset slow -crf 18  -vf scale=$size:-1 $prefix.mp4

# %%
import io
import base64
from IPython.display import HTML

video = io.open('IsoAbund.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
pwd
# Out:
# '/user/NuGrid/NuPPN/frames/ppn/RUN1'
