# %% [markdown]
# # Multi-profile plot example
# This notebook is still being tested on wendi3.

# %%
# %pylab nbagg
#from nugridpy import nugridse as mp
#from nugridpy import mesa as ms

import sys
sys.path.insert(1,"/user/fherwig/NuGridPy")
from nugridpy2 import mesa as ms
from nugridpy2 import mesa as mp



# default data location (try mirror if default
# is not available)
#data_dir="/tmp/nugrid_data"   

# mirror data locations (some mirrors 
# may not be available at some time)

#data_dir="/data/nugrid_cedar"  # may be default    
data_dir="/data/nugrid_rpod4"    
# data_dir="/data/nugrid_vos"    
#data_dir="/data/nugrid_local"

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
prof=ms.mesa_profile('/data/nugrid_rpod4/data/set1ext/set1.2/see_wind/M20.0Z2.0e-02/LOGS/',1000)
# Out:
# 439 in profiles.index file ...
# Found and load nearest profile for cycle 1000
# reading profile/data/nugrid_rpod4/data/set1ext/set1.2/see_wind/M20.0Z2.0e-02/LOGS//log21.data ...
#  reading ...100%

# %%
figure(2)
prof.plot('mass','c12')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Multiple abundance profile plots

# %%
ms.abu_profiles(prof)
# Out:
# <img src="data:image/png;base64,..." width="800">
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Other profiles

# %%
ms.other_profiles(prof)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /user/fherwig/NuGridPy/nugridpy2/mesa.py:3986: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(xxx, np.log10(p.get(thing)), ls=u.linestylecb(ind,a,b)[0],\
# /user/fherwig/NuGridPy/nugridpy2/mesa.py:4110: RuntimeWarning: divide by zero encountered in log
#   thisx = np.log(p.get(thing))+16 if logy[ind] else p.get(thing)
