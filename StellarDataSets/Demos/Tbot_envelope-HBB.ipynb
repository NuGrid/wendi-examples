# %% [markdown]
# # T at the bottom of the convective envelope in a HBB star

# %%
# %pylab 
from nugridpy import mesa as ms
from nugridpy import nugridse as mp


data_dir="/data/nugrid_vos"      # CADC VOspace
data_dir="/data/nugrid_apod2"    # CSA@UVic sshfs

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
st=ms.star_log(mass=6.5,Z=0.0001)
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.5a (Z = 0.0001)
# closest mass is 6.0
# Using old star.logsa file ...
#  reading ...100%

# %%
ifig=129;close(ifig);figure(ifig)
st.kippenhahn(ifig,'model')
#title("Z=0.006, 4Msun")
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
figure(129)
#yylim=ylim(yylim)
yylim=(1.12379, 1.12444)
yylim=ylim(yylim)
xlim(16000,17000)
# Out:
# (16000, 17000)

# %%
yylim
# Out:
# (1.12379, 1.12444)

# %%
pt=mp.se(mass=6,Z=0.0001)
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.5a (Z = 0.0001)
# closest mass is 6.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %%
ifig=130;close(ifig);figure(ifig)
pt.plot('mass','temperature',fname=16800)
xlim(yylim)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
#  reading ['mass']...100%0.374933958054
# (1.12379, 1.12444)
